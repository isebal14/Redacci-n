# %% [markdown]
# # Transportar carga con vehículo de CDIO
# Para transportar la carga de un vehículo y evaluar si este es capaz de realizarlo se realiza el siguiente procedimiento.

# %% [markdown]
# ## Inputs
# $m$: La masa que se quiere trasladar
# $M$: Masa del vehículo

# %%
Inputs
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %% [markdown]
# # LOCOOOO

# %%
aaaaaaaa

# %%
olol
