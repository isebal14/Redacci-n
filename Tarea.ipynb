# %% [markdown]
# # Transportar carga con  vehículo de CDIO
# ### Para transportar la carga de un vehículo

# %%
import numpy
for i in range(10):
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %% [markdown]
# # LOCOOOO
